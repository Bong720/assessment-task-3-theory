# %% [markdown]
# # 📚 Software Automation — Course Contents
# **NSW Software Engineering Stage 6**
#
# ---
# Welcome! This folder contains **12 lessons** that take you from zero to building real AI.
#
# Open each lesson in order. Each one builds on the previous.
#
# ---
#
# ## 🗺️ Lessons
#
# | # | Lesson | Topic | Syllabus Link |
# |---|---|---|---|
# | 01 | [Introduction to Machine Learning](01_Introduction_to_Machine_Learning.ipynb) | What is AI? Build your first model | Weeks 1–2 |
# | 02 | [The ML Pipeline](02_The_ML_Pipeline.ipynb) | Train/test split, RMSE | Weeks 3–4 |
# | 03 | [Working with Data: NumPy & Pandas](03_Working_with_Data_NumPy_and_Pandas.ipynb) | Load and explore real datasets | Weeks 3–4 |
# | 04 | [The Maths Behind the Predictions](04_The_Maths_Behind_the_Predictions.ipynb) | y = wx + b, cost functions | Weeks 5–6 |
# | 05 | [How Does the AI Actually Learn?](05_How_Does_the_AI_Learn.ipynb) | Gradient descent | Weeks 7–9 |
# | 06 | [Writing AI as a Class](06_Writing_AI_as_a_Class.ipynb) | OOP — build a LinearRegression class | Weeks 7–9 |
# | 07 | [More Powerful Predictions](07_More_Powerful_Predictions.ipynb) | Multi-feature regression, scaling | Weeks 7–9 |
# | 08 | [Yes or No? Classification](08_Yes_or_No_Classification.ipynb) | Logistic regression, confusion matrix | Weeks 7–9 |
# | 09 | [Is My AI Too Smart?](09_Is_My_AI_Too_Smart.ipynb) | Overfitting, cross-validation | Weeks 7–9 |
# | 10 | [Decision Trees & KNN](10_Decision_Trees_and_KNN.ipynb) | Two new algorithm types | Weeks 5–6 |
# | 11 | [Neural Networks](11_Neural_Networks.ipynb) | Layers, neurons, MLPClassifier | Extension |
# | 12 | [Responsible AI & Ethics](12_Responsible_AI_and_Ethics.ipynb) | Robodebt, bias, ethical AI | Week 10 |
#
# ---
#
# ## 📋 Each Lesson Includes
#
# * **Concept explanations** — clear, friendly text before any code
# * **Step-by-step demos** — run each cell in order, read the output
# * **5 Exercises** — from easy fill-in-the-blanks to hard from-scratch challenges
# * **Answer Key** — scroll to the bottom of any lesson if you're stuck
#
# ---
#
# ## 📁 Data Files
#
# The following data files are in this folder and used across the lessons:
#
# * `insects.csv` — wing sizes, latitude, sex, and continent of insect specimens
#
# ---
#
# ## ⚡ First Time Setup
#
# If this is your first time opening the course, open **Lesson 01** and run the first cell.
# Each lesson installs only the packages it needs — lightweight and fast!
#
# ---
#
# *NSW Software Engineering 11–12 | Software Automation focus area*
